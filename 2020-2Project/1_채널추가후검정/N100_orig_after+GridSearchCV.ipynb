# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
N100_df = pd.read_csv('N100_mergedTrialData_채널추가_통합.csv')
N100_df.head()
# Out:
#    subject  trial  condition  group   Fz_N100   FCz_N100    Cz_N100  FC3_N100  \
# 0        1      1          1      0 -9.761338 -11.545219 -16.775214 -3.576595
# 1        1      2          1      0  8.717519  11.462619   7.979110  9.429738
# 2        1      3          1      0 -4.027286  -3.992038  -1.104119 -3.319471
# 3        1      4          1      0  0.394095  -0.663186  -1.372871  3.974643
# 4        1      5          1      0 -9.368090 -12.029829 -10.280100 -7.846471
#
#     FC4_N100    C3_N100    C4_N100   CP3_N100   CP4_N100  AFz_N100    F2_N100
# 0 -11.745167  -0.895419 -16.679205  -5.854429 -14.473143 -5.620110 -11.518548
# 1   6.912862   6.242343   4.690100   2.795200   1.938529  7.087043   9.521781
# 2   0.321314   0.419538   0.030619   2.828195   2.731533 -5.319305   1.080852
# 3  -1.613667   2.376024  -1.504500   2.945000  -1.082224 -0.270219  -3.785038
# 4  -8.170986 -10.192229  -6.907095 -14.041000  -9.666710 -9.386048 -11.431033

# %%
from pprint import pprint
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_curve, auc

# %%
col_names = N100_df.columns.values
X = N100_df[col_names[4:]]
Y = N100_df[col_names[3]]

# %%
X.head(5)
# Out:
#     Fz_N100   FCz_N100    Cz_N100  FC3_N100   FC4_N100    C3_N100    C4_N100  \
# 0 -9.761338 -11.545219 -16.775214 -3.576595 -11.745167  -0.895419 -16.679205
# 1  8.717519  11.462619   7.979110  9.429738   6.912862   6.242343   4.690100
# 2 -4.027286  -3.992038  -1.104119 -3.319471   0.321314   0.419538   0.030619
# 3  0.394095  -0.663186  -1.372871  3.974643  -1.613667   2.376024  -1.504500
# 4 -9.368090 -12.029829 -10.280100 -7.846471  -8.170986 -10.192229  -6.907095
#
#     CP3_N100   CP4_N100  AFz_N100    F2_N100
# 0  -5.854429 -14.473143 -5.620110 -11.518548
# 1   2.795200   1.938529  7.087043   9.521781
# 2   2.828195   2.731533 -5.319305   1.080852
# 3   2.945000  -1.082224 -0.270219  -3.785038
# 4 -14.041000  -9.666710 -9.386048 -11.431033

# %%
Y.head(5)
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: group, dtype: int64

# %%
def train_val_test_split(X, Y, test_size=0.3, random_state=123):
    X_train, X_test, Y_train, Y_test = train_test_split(X, Y, 
                                                        test_size=test_size, 
                                                        random_state=random_state)
   
    return X_train, X_test, Y_train, Y_test

# %%
X_train, X_test, Y_train, Y_test = train_val_test_split(X, Y,
                                                                      test_size=0.2,
                                                                      random_state=123)

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (18560, 11)
# (4641, 11)

# %%
X_condition = N100_df[col_names[2:]]
Y_condition = N100_df[col_names[2:4]]

# %%
Y_condition.head()
# Out:
#    condition  group
# 0          1      0
# 1          1      0
# 2          1      0
# 3          1      0
# 4          1      0

# %%
X_condition.head()
# Out:
#    condition  group   Fz_N100   FCz_N100    Cz_N100  FC3_N100   FC4_N100  \
# 0          1      0 -9.761338 -11.545219 -16.775214 -3.576595 -11.745167
# 1          1      0  8.717519  11.462619   7.979110  9.429738   6.912862
# 2          1      0 -4.027286  -3.992038  -1.104119 -3.319471   0.321314
# 3          1      0  0.394095  -0.663186  -1.372871  3.974643  -1.613667
# 4          1      0 -9.368090 -12.029829 -10.280100 -7.846471  -8.170986
#
#      C3_N100    C4_N100   CP3_N100   CP4_N100  AFz_N100    F2_N100
# 0  -0.895419 -16.679205  -5.854429 -14.473143 -5.620110 -11.518548
# 1   6.242343   4.690100   2.795200   1.938529  7.087043   9.521781
# 2   0.419538   0.030619   2.828195   2.731533 -5.319305   1.080852
# 3   2.376024  -1.504500   2.945000  -1.082224 -0.270219  -3.785038
# 4 -10.192229  -6.907095 -14.041000  -9.666710 -9.386048 -11.431033

# %%
X_condition=X_condition.drop('group', axis=1)
X_condition.head()
# Out:
#    condition   Fz_N100   FCz_N100    Cz_N100  FC3_N100   FC4_N100    C3_N100  \
# 0          1 -9.761338 -11.545219 -16.775214 -3.576595 -11.745167  -0.895419
# 1          1  8.717519  11.462619   7.979110  9.429738   6.912862   6.242343
# 2          1 -4.027286  -3.992038  -1.104119 -3.319471   0.321314   0.419538
# 3          1  0.394095  -0.663186  -1.372871  3.974643  -1.613667   2.376024
# 4          1 -9.368090 -12.029829 -10.280100 -7.846471  -8.170986 -10.192229
#
#      C4_N100   CP3_N100   CP4_N100  AFz_N100    F2_N100
# 0 -16.679205  -5.854429 -14.473143 -5.620110 -11.518548
# 1   4.690100   2.795200   1.938529  7.087043   9.521781
# 2   0.030619   2.828195   2.731533 -5.319305   1.080852
# 3  -1.504500   2.945000  -1.082224 -0.270219  -3.785038
# 4  -6.907095 -14.041000  -9.666710 -9.386048 -11.431033

# %%
Y_condition1=Y_condition[Y_condition['condition']==1]
Y_condition1.head(101)
# Out:
#      condition  group
# 0            1      0
# 1            1      0
# 2            1      0
# 3            1      0
# 4            1      0
# 5            1      0
# 6            1      0
# 7            1      0
# 8            1      0
# 9            1      0
# 10           1      0
# 11           1      0
# 12           1      0
# 13           1      0
# 14           1      0
# 15           1      0
# 16           1      0
# 17           1      0
# 18           1      0
# 19           1      0
# 20           1      0
# 21           1      0
# 22           1      0
# 23           1      0
# 24           1      0
# 25           1      0
# 26           1      0
# 27           1      0
# 28           1      0
# 29           1      0
# ..         ...    ...
# 71           1      0
# 72           1      0
# 73           1      0
# 74           1      0
# 75           1      0
# 76           1      0
# 77           1      0
# 78           1      0
# 79           1      0
# ...

# %%
Y_condition1=Y_condition1.drop('condition', axis=1)
Y_condition1.head()
# Out:
#    group
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0

# %%
Y_condition2=Y_condition[Y_condition['condition']==2]
Y_condition2.head(101)
# Out:
#      condition  group
# 100          2      0
# 101          2      0
# 102          2      0
# 103          2      0
# 104          2      0
# 105          2      0
# 106          2      0
# 107          2      0
# 108          2      0
# 109          2      0
# 110          2      0
# 111          2      0
# 112          2      0
# 113          2      0
# 114          2      0
# 115          2      0
# 116          2      0
# 117          2      0
# 118          2      0
# 119          2      0
# 120          2      0
# 121          2      0
# 122          2      0
# 123          2      0
# 124          2      0
# 125          2      0
# 126          2      0
# 127          2      0
# 128          2      0
# 129          2      0
# ..         ...    ...
# 171          2      0
# 172          2      0
# 173          2      0
# 174          2      0
# 175          2      0
# 176          2      0
# 177          2      0
# 178          2      0
# 179          2      0
# ...

# %%
Y_condition2=Y_condition2.drop('condition', axis=1)
Y_condition2.head()
# Out:
#      group
# 100      0
# 101      0
# 102      0
# 103      0
# 104      0

# %%
Y_condition3=Y_condition[Y_condition['condition']==3]
Y_condition3.head(101)
# Out:
#      condition  group
# 194          3      0
# 195          3      0
# 196          3      0
# 197          3      0
# 198          3      0
# 199          3      0
# 200          3      0
# 201          3      0
# 202          3      0
# 203          3      0
# 204          3      0
# 205          3      0
# 206          3      0
# 207          3      0
# 208          3      0
# 209          3      0
# 210          3      0
# 211          3      0
# 212          3      0
# 213          3      0
# 214          3      0
# 215          3      0
# 216          3      0
# 217          3      0
# 218          3      0
# 219          3      0
# 220          3      0
# 221          3      0
# 222          3      0
# 223          3      0
# ..         ...    ...
# 265          3      0
# 266          3      0
# 267          3      0
# 268          3      0
# 269          3      0
# 270          3      0
# 271          3      0
# 272          3      0
# 273          3      0
# ...

# %%
Y_condition3=Y_condition3.drop('condition', axis=1)
Y_condition3.head()
# Out:
#      group
# 194      0
# 195      0
# 196      0
# 197      0
# 198      0

# %%
X_condition1=X_condition[X_condition['condition']==1]
X_condition1.head(101)
# Out:
#      condition    Fz_N100   FCz_N100    Cz_N100   FC3_N100   FC4_N100  \
# 0            1  -9.761338 -11.545219 -16.775214  -3.576595 -11.745167
# 1            1   8.717519  11.462619   7.979110   9.429738   6.912862
# 2            1  -4.027286  -3.992038  -1.104119  -3.319471   0.321314
# 3            1   0.394095  -0.663186  -1.372871   3.974643  -1.613667
# 4            1  -9.368090 -12.029829 -10.280100  -7.846471  -8.170986
# 5            1 -10.790257 -10.572367 -14.636533  -9.880271 -15.229224
# 6            1   5.616595   9.261605  11.472643   5.892076   3.369305
# 7            1  12.262348  14.245062  16.989962  10.314271   9.561067
# 8            1  -0.596852  -1.241681  -3.727729   8.685595  -4.913276
# 9            1  -6.015471  -7.863443  -9.716157  -6.245338  -5.074048
# 10           1  -8.439419 -11.605800  -6.869338  -4.685543  -5.668019
# 11           1   8.009243  10.472452   7.978967   6.232681  11.941276
# ...

# %%
X_condition2=X_condition[X_condition['condition']==2]
X_condition2.head(101)
# Out:
#      condition    Fz_N100   FCz_N100    Cz_N100   FC3_N100   FC4_N100  \
# 100          2 -16.716552 -20.971295 -20.478290 -10.182510 -19.729390
# 101          2  -3.722819   0.513381   5.512324  -6.093929  -3.810562
# 102          2  -8.247662  -9.755552 -10.301010  -4.977605  -2.362848
# 103          2  -8.027805  -7.270267  -6.318910 -13.784110  -3.382119
# 104          2  -6.368943  -8.376862 -10.965705 -16.191648  -9.046586
# 105          2 -23.887971 -25.746367 -26.506876 -17.793667 -18.992681
# 106          2 -11.405690 -11.201986 -12.185310 -11.642905 -15.096833
# 107          2  -2.690552   0.353181  -0.090357   0.199086  -5.209033
# 108          2  11.067590  11.486171   7.105162   9.595990   7.694167
# 109          2   2.553186  -0.695638  -7.052710   3.339743  -0.394033
# 110          2  -4.984733  -5.523571  -7.916448  -2.184229 -14.868343
# 111          2 -12.287462 -13.074610 -15.026086 -11.287043  -9.233276
# ...

# %%
X_condition3=X_condition[X_condition['condition']==3]
X_condition3.head(101)
# Out:
#      condition    Fz_N100   FCz_N100    Cz_N100   FC3_N100   FC4_N100  \
# 194          3   7.927462  10.191724  14.238219   6.325543   9.125038
# 195          3   1.525724   3.350157   4.831110   5.704062   1.612810
# 196          3   8.472619  12.202405  15.034671   6.784305  12.998590
# 197          3   6.251105  11.988548  18.587343  13.116338   8.820376
# 198          3   4.445529   1.646410  -2.357400   6.164052  -2.160619
# 199          3   1.720248   0.753138   2.764776  -0.042848   3.739200
# 200          3  -4.061529  -5.716195  -8.323124  -2.957110  -7.120652
# 201          3   5.132795   5.039795   8.241124   6.452662   7.013976
# 202          3   0.083867   0.035476   0.798010  -2.412929  -2.835867
# 203          3  11.660967  12.732457  13.322486   9.178481  14.236833
# 204          3  -0.296005  -3.840743  -3.066705  -3.977671   0.365671
# 205          3 -15.946357 -18.309043 -20.380252 -13.787514 -18.009971
# ...

# %%
X_condition1_train, X_condition1_test, Y_condition1_train, Y_condition1_test = train_val_test_split(X_condition1, Y_condition1,
                                                                      
                                                                      test_size=0.2,
                                                                      random_state=123)

# %%
print(X_condition1_train.shape)
print(X_condition1_test.shape)
print(Y_condition1_train.shape)
print(Y_condition1_test.shape)
# Out:
# (6268, 12)
# (1568, 12)
# (6268, 1)
# (1568, 1)

# %%
X_condition2_train, X_condition2_test, Y_condition2_train, Y_condition2_test = train_val_test_split(X_condition2, Y_condition2,
                                                                      
                                                                      test_size=0.2,
                                                                      random_state=123)

# %%
X_condition3_train, X_condition3_test, Y_condition3_train, Y_condition3_test = train_val_test_split(X_condition3, Y_condition3,
                                                                      
                                                                      test_size=0.2,
                                                                      random_state=123)

# %%
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedKFold
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# -Condition1 학습

# %%
rkfold = RepeatedKFold(n_splits=7, n_repeats=3, random_state=42) 
param_grid = {'weights':['uniform', 'distance'],
'n_neighbors': [9, 11, 13, 15]}
grid = GridSearchCV(KNeighborsClassifier(), param_grid, cv=rkfold, return_train_score=True, scoring='accuracy', iid=False)
grid.fit(X_condition1_train, Y_condition1_train.values.ravel())
grid.score(X_condition1_test, Y_condition1_test), grid.best_params_, grid.best_score_
# Out:
# (0.5739795918367347,
#  {'n_neighbors': 15, 'weights': 'uniform'},
#  0.5767396937825409)

# %%
rkfold = RepeatedKFold(n_splits=5, n_repeats=3, random_state=42) #tol,intercept_scaling, class_weight, random_state
param_grid = {'n_estimators': [15, 20, 25],
'max_features': ['auto', 'sqrt', 'log2']}
grid = GridSearchCV(RandomForestClassifier(), param_grid, cv=rkfold, return_train_score=True, scoring='accuracy', iid=False)
grid.fit(X_condition1_train, Y_condition1_train.values.ravel())
grid.score(X_condition1_test, Y_condition1_test), grid.best_params_, grid.best_score_
# Out:
# (0.5899234693877551,
#  {'max_features': 'sqrt', 'n_estimators': 25},
#  0.5749319973371723)

# %% [markdown]
# -Condition2 학습

# %%
rkfold = RepeatedKFold(n_splits=7, n_repeats=3, random_state=42) 
param_grid = {'weights':['uniform', 'distance'],
'n_neighbors': [9, 11, 13, 15]}
grid = GridSearchCV(KNeighborsClassifier(), param_grid, cv=rkfold, return_train_score=True, scoring='accuracy', iid=False)
grid.fit(X_condition2_train, Y_condition2_train.values.ravel())
grid.score(X_condition2_test, Y_condition2_test), grid.best_params_, grid.best_score_
# Out:
# (0.5520628683693517,
#  {'n_neighbors': 15, 'weights': 'distance'},
#  0.591251638269987)

# %%
rkfold = RepeatedKFold(n_splits=5, n_repeats=3, random_state=42) #tol,intercept_scaling, class_weight, random_state
param_grid = {'n_estimators': [15, 20, 25],
'max_features': ['auto', 'sqrt', 'log2']}
grid = GridSearchCV(RandomForestClassifier(), param_grid, cv=rkfold, return_train_score=True, scoring='accuracy', iid=False)
grid.fit(X_condition2_train, Y_condition2_train.values.ravel())
grid.score(X_condition2_test, Y_condition2_test), grid.best_params_, grid.best_score_
# Out:
# (0.5828421741977734,
#  {'max_features': 'sqrt', 'n_estimators': 25},
#  0.5881932752424556)

# %% [markdown]
# -Condition3 학습

# %%
rkfold = RepeatedKFold(n_splits=7, n_repeats=3, random_state=42) 
param_grid = {'weights':['uniform', 'distance'],
'n_neighbors': [9, 11, 13, 15]}
grid = GridSearchCV(KNeighborsClassifier(), param_grid, cv=rkfold, return_train_score=True, scoring='accuracy', iid=False)
grid.fit(X_condition3_train, Y_condition3_train.values.ravel())
grid.score(X_condition3_test, Y_condition3_test), grid.best_params_, grid.best_score_
# Out:
# (0.5733678086619263,
#  {'n_neighbors': 15, 'weights': 'distance'},
#  0.568990493662401)

# %%
rkfold = RepeatedKFold(n_splits=5, n_repeats=3, random_state=42) #tol,intercept_scaling, class_weight, random_state
param_grid = {'n_estimators': [15, 20, 25],
'max_features': ['auto', 'sqrt', 'log2']}
grid = GridSearchCV(RandomForestClassifier(), param_grid, cv=rkfold, return_train_score=True, scoring='accuracy', iid=False)
grid.fit(X_condition3_train, Y_condition3_train.values.ravel())
grid.score(X_condition3_test, Y_condition3_test), grid.best_params_, grid.best_score_
# Out:
# (0.5778926955397543,
#  {'max_features': 'log2', 'n_estimators': 25},
#  0.577878803313208)
