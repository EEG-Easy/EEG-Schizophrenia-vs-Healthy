# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pprint import pprint
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_curve, auc

# %%
EEG_df = pd.read_csv('P300.csv')
EEG_df.head()
# Out:
#    subject  trial  condition  group  F1_P300  FC3_P300  FC1_P300  AFz_P300  \
# 0        1      1          1      0  13.9836   15.0689   15.5019   15.9091
# 1        1      2          1      0  31.0895   39.5852   33.1532   20.3352
# 2        1      3          1      0  21.0610   22.0997   20.7909   15.9415
# 3        1      4          1      0  23.6089   25.5625   34.2806   24.7410
# 4        1      5          1      0   7.4142   13.6209    5.7112   10.4210
#
#    Fz_P300  F2_P300  FCz_P300
# 0   9.5313   7.4203   11.3167
# 1  28.2222  32.9192   34.6021
# 2  27.4982  27.6248   23.9452
# 3  27.8989  23.7729   30.4638
# 4   6.1201   8.9196    5.1835

# %%
list = []
for i in range (0, len(EEG_df)):
    eeg = EEG_df.iloc[i].F1_P300
    if eeg < 0: 
        eeg = 0 
    list.append(eeg)

# %%
list[100:1000]
# Out:
# [15.786,
#  30.0906,
#  25.4125,
#  7.843,
#  31.7779,
#  7.2063,
#  7.9734,
#  2.2548,
#  25.134,
#  11.2743,
#  24.4723,
#  6.6911,
#  15.1262,
#  18.4338,
#  3.9028,
#  7.4586,
#  13.3908,
#  11.8518,
#  3.7306,
#  6.1368,
#  11.4334,
#  30.3748,
#  18.3726,
#  22.0211,
#  3.6704,
#  8.2533,
#  25.366999999999997,
#  11.5101,
#  12.472000000000001,
#  25.755,
#  9.7684,
#  21.5075,
#  13.8167,
#  3.0516,
#  26.4646,
#  17.0132,
#  7.1099,
#  7.6702,
#  12.4552,
#  8.6167,
#  8.1117,
#  0.3306,
#  12.8798,
#  6.8306,
#  19.2829,
#  8.9758,
#  27.1963,
#  15.2583,
#  30.1273,
#  24.7413,
#  33.8677,
#  12.4222,
#  17.0514,
#  7.8453,
#  16.8245,
#  19.6374,
#  11.2807,
#  18.980999999999998,
#  7.0019,
#  12.2756,
#  15.5916,
#  12.4287,
#  18.97,
#  9.062999999999999,
#  15.8851,
#  9.1505,
#  18.9328,
#  15.152999999999999,
#  25.3347,
#  6.875,
#  11.9449,
#  15.8066,
#  16.5622,
#  14.6927,
#  2.0635,
#  24.406999999999996,
#  23.5368,
#  11.3227,
#  12.6928,
#  38.7193,
# ...

# %%
EEG_df['F1_P300']=list

# %%
list = []
for i in range (0, len(EEG_df)):
    eeg = EEG_df.iloc[i].FC3_P300
    if eeg < 0: 
        eeg = 0 
    list.append(eeg)

# %%
EEG_df['FC3_P300']=list

# %%
list = []
for i in range (0, len(EEG_df)):
    eeg = EEG_df.iloc[i].FC1_P300
    if eeg < 0: 
        eeg = 0 
    list.append(eeg)

# %%
EEG_df['FC1_P300']=list

# %%
list = []
for i in range (0, len(EEG_df)):
    eeg = EEG_df.iloc[i].AFz_P300
    if eeg < 0: 
        eeg = 0 
    list.append(eeg)

# %%
EEG_df['AFz_P300']=list

# %%
list = []
for i in range (0, len(EEG_df)):
    eeg = EEG_df.iloc[i].Fz_P300
    if eeg < 0: 
        eeg = 0 
    list.append(eeg)

# %%
EEG_df['Fz_P300']=list

# %%
list = []
for i in range (0, len(EEG_df)):
    eeg = EEG_df.iloc[i].F2_P300
    if eeg < 0: 
        eeg = 0 
    list.append(eeg)

# %%
EEG_df['F2_P300']=list

# %%
list = []
for i in range (0, len(EEG_df)):
    eeg = EEG_df.iloc[i].FCz_P300
    if eeg < 0: 
        eeg = 0 
    list.append(eeg)

# %%
EEG_df['FCz_P300']=list

# %%
col_names = EEG_df.columns.values
X = EEG_df[col_names[0:]]
Y = EEG_df[col_names[2:4]]

# %%
X = X.drop(['subject','trial'], axis=1)

# %%
X_condition1=X[X['condition']==1]
X_condition2=X[X['condition']==2]
X_condition3=X[X['condition']==3]

X_condition1=X_condition1.drop('condition',axis=1)
X_condition2=X_condition2.drop('condition',axis=1)
X_condition3=X_condition3.drop('condition',axis=1)

X_condition1=X_condition1.drop('group',axis=1)
X_condition2=X_condition2.drop('group',axis=1)
X_condition3=X_condition3.drop('group',axis=1)
X_condition1.head(5)
# Out:
#    F1_P300  FC3_P300  FC1_P300  AFz_P300  Fz_P300  F2_P300  FCz_P300
# 0  13.9836   15.0689   15.5019   15.9091   9.5313   7.4203   11.3167
# 1  31.0895   39.5852   33.1532   20.3352  28.2222  32.9192   34.6021
# 2  21.0610   22.0997   20.7909   15.9415  27.4982  27.6248   23.9452
# 3  23.6089   25.5625   34.2806   24.7410  27.8989  23.7729   30.4638
# 4   7.4142   13.6209    5.7112   10.4210   6.1201   8.9196    5.1835

# %%
Y_condition1=Y[Y['condition']==1]
Y_condition2=Y[Y['condition']==2]
Y_condition3=Y[Y['condition']==3]

Y_condition1=Y_condition1.drop('condition',axis=1)
Y_condition2=Y_condition2.drop('condition',axis=1)
Y_condition3=Y_condition3.drop('condition',axis=1)
Y_condition1.head(5)
# Out:
#    group
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0

# %%
def train_val_test_split(X, Y, test_size=0.3, random_state=123):
    X_train, X_test, Y_train, Y_test = train_test_split(X, Y, 
                                                        test_size=test_size, 
                                                        random_state=random_state)
   
    return X_train, X_test, Y_train, Y_test

# %%
X_condition1_train, X_condition1_test, Y_condition1_train, Y_condition1_test = train_val_test_split(X_condition1, Y_condition1,
                                                                      
                                                                      test_size=0.3,
                                                                      random_state=123)

# %%
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedKFold
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV

# %%
rkfold = RepeatedKFold(n_splits=7, n_repeats=3, random_state=42) 
param_grid = {'weights':['uniform', 'distance'],
'n_neighbors': [9, 11, 13, 15, 17]}
grid = GridSearchCV(KNeighborsClassifier(), param_grid, cv=rkfold, return_train_score=True, scoring='accuracy', iid=False)
grid.fit(X_condition1_train, Y_condition1_train)
grid.score(X_condition1_test, Y_condition1_test), grid.best_params_, grid.best_score_
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:528: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:528: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:528: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# ...

# %%
rkfold = RepeatedKFold(n_splits=7, n_repeats=3, random_state=42) #tol,intercept_scaling, class_weight, random_state
param_grid = {'n_estimators': [15, 20, 25],
'max_features': ['auto', 'sqrt', 'log2']}
grid = GridSearchCV(RandomForestClassifier(), param_grid, cv=rkfold, return_train_score=True, scoring='accuracy', iid=False)
grid.fit(X_condition1_train, Y_condition1_train)
grid.score(X_condition1_test, Y_condition1_test), grid.best_params_, grid.best_score_
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:528: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:528: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:528: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# ...

# %%
rkfold = RepeatedKFold(n_splits=7, n_repeats=3, random_state=42) #tol,intercept_scaling, class_weight, random_state
param_grid = {'class_weight': [None, 'balanced'],
'max_depth': [3, 4, 5, 6, 7]}
grid = GridSearchCV(DecisionTreeClassifier(), param_grid, cv=rkfold, return_train_score=True, scoring='accuracy', iid=False)
grid.fit(X_condition1_train, Y_condition1_train)
grid.score(X_condition1_test, Y_condition1_test), grid.best_params_, grid.best_score_
# Out:
# (0.6018715440238197,
#  {'class_weight': None, 'max_depth': 3},
#  0.6055301430917195)

# %%
rkfold = RepeatedKFold(n_splits=7, n_repeats=3, random_state=42) #tol,intercept_scaling, class_weight, random_state
param_grid = {'penalty': ['l1', 'l2'],
'C': [0.1, 1, 10, 1e2, 1e3, 1e4, 1e5, 1e6]}
grid = GridSearchCV(LogisticRegression(), param_grid, cv=rkfold, return_train_score=True, scoring='accuracy', iid=False)
grid.fit(X_condition1_train, Y_condition1_train)
grid.score(X_condition1_test, Y_condition1_test), grid.best_params_, grid.best_score_
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...
