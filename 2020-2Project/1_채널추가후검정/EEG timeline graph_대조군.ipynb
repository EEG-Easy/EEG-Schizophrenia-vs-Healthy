# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
color = sns.color_palette()
sns.set_style('darkgrid')
import warnings
warnings.filterwarnings('ignore')

# %%
df11 = pd.read_csv('11.csv')
col_names = df11.columns.values
df11_AFz = df11[col_names[40:41]]
df11_AFz = df11_AFz.iloc[:3072]
df11_AFz.head(5)
# Out:
#    -4.8502
# 0  -3.4236
# 1  -3.8145
# 2  -4.4493
# 3  -5.2929
# 4  -4.9724

# %%
df12 = pd.read_csv('12.csv')
col_names = df12.columns.values
df12_AFz = df12[col_names[40:41]]
df12_AFz = df12_AFz.iloc[:3072]
df12_AFz.head(5)
# Out:
#    -7.1303
# 0  -5.2963
# 1  -3.6568
# 2  -1.8377
# 3  -1.6874
# 4  -1.6960

# %%
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = [20, 5]
c = [i for i in range(1, 3073, 1)]  # generating index 
fig = plt.figure()
plt.plot(c,df11_AFz, color="blue", linewidth=1.5, linestyle="-")
fig.suptitle('EEG Graph', fontsize=20) # Plot heading 
plt.xlabel('TIME', fontsize=18)  # X-label
plt.ylabel('EEG', fontsize=16)   # Y-label
# Out:
# Text(0, 0.5, 'EEG')

# %%
plt.rcParams['figure.figsize'] = [20, 5]
c = [i for i in range(1, 3073, 1)]  # generating index 
fig = plt.figure()
plt.plot(c,df11_AFz, color="blue", linewidth=1.5, linestyle="-")
fig.suptitle('EEG Graph', fontsize=20) # Plot heading 
plt.xlabel('TIME', fontsize=18)  # X-label
plt.ylabel('EEG', fontsize=16)   # Y-label

plt.xlim(1200, 2000)
# Out:
# (1200, 2000)

# %%
plt.rcParams['figure.figsize'] = [20, 5]
c = [i for i in range(1, 3073, 1)]  # generating index 
fig = plt.figure()
plt.plot(c,df12_AFz, color="blue", linewidth=1.5, linestyle="-")
fig.suptitle('EEG Graph', fontsize=20) # Plot heading 
plt.xlabel('TIME', fontsize=18)  # X-label
plt.ylabel('EEG', fontsize=16)   # Y-label
# Out:
# Text(0, 0.5, 'EEG')
